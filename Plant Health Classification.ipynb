# %% [markdown]
# ## Plant Health Classification

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import Dataset

# %%
plants_df = pd.read_csv('plant_health_data.csv')
plants_df.head(10)
# Out:
#                     Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 0  2024-10-03 10:54:53.407995         1      27.521109            22.240245
# 1  2024-10-03 16:54:53.407995         1      14.835566            21.706763
# 2  2024-10-03 22:54:53.407995         1      17.086362            21.180946
# 3  2024-10-04 04:54:53.407995         1      15.336156            22.593302
# 4  2024-10-04 10:54:53.407995         1      39.822216            28.929001
# 5  2024-10-04 16:54:53.407995         1      29.208365            24.364209
# 6  2024-10-04 22:54:53.407995         1      16.351409            23.022895
# 7  2024-10-05 04:54:53.407995         1      33.307697            20.199186
# 8  2024-10-05 10:54:53.407995         1      12.722726            25.467645
# 9  2024-10-05 16:54:53.407995         1      13.244641            27.636685
#
#    Soil_Temperature   Humidity  Light_Intensity   Soil_pH  Nitrogen_Level  \
# 0         21.900435  55.291904       556.172805  5.581955       10.003650
# 1         18.680892  63.949181       596.136721  7.135705       30.712562
# 2         15.392939  67.837956       591.124627  5.656852       29.337002
# 3         22.778394  58.190811       241.412476  5.584523       16.966621
# 4         18.100937  63.772036       444.493830  5.919707       10.944961
# 5         22.551551  46.392811       496.233040  6.157931       10.060115
# 6         17.950348  56.906212       454.639214  7.075570       28.010890
# 7         16.298221  56.326217       455.698975  6.105039       15.871379
# 8         16.693036  47.544175       635.057034  6.487872       45.630530
# 9         23.620169  65.615769       393.247781  5.580117       44.422996
#
#    Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# 0         45.806852        39.076199            35.703006
# 1         25.394393        17.944826            27.993296
# 2         27.573892        35.706530            43.646308
# 3         26.180705        26.257746            37.838095
# 4         37.898907        37.654483            48.265812
# 5         15.610667        21.782672            45.052181
# 6         32.564592        39.934656            49.232936
# 7         10.454182        24.853727            33.925178
# 8         47.459179        12.451933            47.750350
# 9         39.811114        38.613020            35.613519
#
#    Electrochemical_Signal Plant_Health_Status
# 0                0.941402         High Stress
# 1                0.164899         High Stress
# 2                1.081728         High Stress
# 3                1.186088         High Stress
# 4                1.609805         High Stress
# 5                0.034302         High Stress
# 6                1.272921         High Stress
# 7                1.675545     Moderate Stress
# 8                1.391798         High Stress
# 9                0.962509         High Stress

# %% [markdown]
# #### Shape

# %%
plants_df.shape
# Out:
# (1200, 14)

# %% [markdown]
# #### Columns

# %%
plants_df.columns
# Out:
# Index(['Timestamp', 'Plant_ID', 'Soil_Moisture', 'Ambient_Temperature',
#        'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH',
#        'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level',
#        'Chlorophyll_Content', 'Electrochemical_Signal', 'Plant_Health_Status'],
#       dtype='object')

# %% [markdown]
# #### DataFrame Information

# %%
plants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               1200 non-null   object
#  1   Plant_ID                1200 non-null   int64
#  2   Soil_Moisture           1200 non-null   float64
#  3   Ambient_Temperature     1200 non-null   float64
#  4   Soil_Temperature        1200 non-null   float64
#  5   Humidity                1200 non-null   float64
#  6   Light_Intensity         1200 non-null   float64
#  7   Soil_pH                 1200 non-null   float64
#  8   Nitrogen_Level          1200 non-null   float64
#  9   Phosphorus_Level        1200 non-null   float64
#  10  Potassium_Level         1200 non-null   float64
#  11  Chlorophyll_Content     1200 non-null   float64
#  12  Electrochemical_Signal  1200 non-null   float64
#  13  Plant_Health_Status     1200 non-null   object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 131.4+ KB

# %% [markdown]
# #### Quantiles

# %%
plants_df.describe()
# Out:
#           Plant_ID  Soil_Moisture  Ambient_Temperature  Soil_Temperature  \
# count  1200.000000    1200.000000          1200.000000       1200.000000
# mean      5.500000      25.106918            23.999130         19.957794
# std       2.873479       8.677725             3.441561          2.932073
# min       1.000000      10.000724            18.001993         15.003710
# 25%       3.000000      17.131893            21.101766         17.353027
# 50%       5.500000      25.168333            23.889044         19.911473
# 75%       8.000000      32.370231            27.042634         22.596851
# max      10.000000      39.993164            29.990886         24.995929
#
#           Humidity  Light_Intensity      Soil_pH  Nitrogen_Level  \
# count  1200.000000      1200.000000  1200.000000     1200.000000
# mean     54.853165       612.637265     6.524102       30.106751
# std       8.784916       228.318853     0.581755       11.514396
# min      40.028758       200.615482     5.507392       10.003650
# 25%      47.019694       416.878983     6.026042       20.249774
# 50%      54.692069       617.240221     6.540524       30.138590
# 75%      62.451053       811.474690     7.030039       40.184737
# max      69.968871       999.856262     7.497823       49.951136
#
#        Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# count       1200.000000      1200.000000          1200.000000
# mean          30.264484        30.112088            34.749591
# std           11.466846        11.668085             8.766995
# min           10.017690        10.000606            20.025511
# 25%           20.894445        19.585561            27.463350
# 50%           30.019385        30.495054            34.433427
# 75%           40.131459        40.108296            42.232637
# max           49.980700        49.981945            49.990811
#
#        Electrochemical_Signal
# count             1200.000000
# mean                 0.987764
# std                  0.575116
# min                  0.002376
# 25%                  0.487982
# 50%                  0.981647
# 75%                  1.473142
# max                  1.996116

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Remove Duplicates

# %%
plants_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Remove Nulls

# %%
plants_df.isnull().sum()
# Out:
# Timestamp                 0
# Plant_ID                  0
# Soil_Moisture             0
# Ambient_Temperature       0
# Soil_Temperature          0
# Humidity                  0
# Light_Intensity           0
# Soil_pH                   0
# Nitrogen_Level            0
# Phosphorus_Level          0
# Potassium_Level           0
# Chlorophyll_Content       0
# Electrochemical_Signal    0
# Plant_Health_Status       0
# dtype: int64

# %% [markdown]
# #### Type Conversion

# %%
plants_df['Timestamp'] = pd.to_datetime(plants_df['Timestamp'])

# %% [markdown]
# #### Features Extraction

# %%
plants_df['Day'] = plants_df['Timestamp'].dt.day
plants_df['Time'] = plants_df['Timestamp'].dt.hour

# %%
plants_df.head(3)
# Out:
#                    Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 0 2024-10-03 10:54:53.407995         1      27.521109            22.240245
# 1 2024-10-03 16:54:53.407995         1      14.835566            21.706763
# 2 2024-10-03 22:54:53.407995         1      17.086362            21.180946
#
#    Soil_Temperature   Humidity  Light_Intensity   Soil_pH  Nitrogen_Level  \
# 0         21.900435  55.291904       556.172805  5.581955       10.003650
# 1         18.680892  63.949181       596.136721  7.135705       30.712562
# 2         15.392939  67.837956       591.124627  5.656852       29.337002
#
#    Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# 0         45.806852        39.076199            35.703006
# 1         25.394393        17.944826            27.993296
# 2         27.573892        35.706530            43.646308
#
#    Electrochemical_Signal Plant_Health_Status  Day  Time
# 0                0.941402         High Stress    3    10
# 1                0.164899         High Stress    3    16
# 2                1.081728         High Stress    3    22

# %% [markdown]
# #### Drop Unwanted Columns

# %%
plants_df.drop(columns='Timestamp', inplace=True)

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Columns : 'Soil_Moisture', 'Ambient_Temperature', 'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH'  'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level   'Chlorophyll_Content', 'Electrochemical_Signal'

# %%
plt.subplots(3,4,figsize=(16,12))
plt.subplots_adjust(wspace=0.3, hspace=0.3)

columns = ['Soil_Moisture', 'Ambient_Temperature', 'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH',
       'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level', 'Chlorophyll_Content', 'Electrochemical_Signal']
k = 1
for i in columns:
    plt.subplot(3,4,k)
    sns.histplot(x = i, data = plants_df, kde = True)
    plt.title(f'Distribution of {i}')
    k += 1

plt.show()

# %%
plt.subplots(3,4,figsize=(16,12))
plt.subplots_adjust(wspace=0.3, hspace=0.3)

columns = ['Soil_Moisture', 'Ambient_Temperature', 'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH',
       'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level', 'Chlorophyll_Content', 'Electrochemical_Signal']
k = 1
for i in columns:
    plt.subplot(3,4,k)
    sns.boxplot(x = i, data = plants_df)
    plt.title(f'Distribution of {i}')
    k += 1

plt.show()

# %%
plt.subplots(3,4,figsize=(16,12))
plt.subplots_adjust(wspace=0.3, hspace=0.5)

columns = ['Soil_Moisture', 'Ambient_Temperature', 'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH',
       'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level', 'Chlorophyll_Content', 'Electrochemical_Signal']
k = 1
for i in columns:
    plt.subplot(3,4,k)
    sns.barplot(y = i, x = 'Plant_Health_Status', data = plants_df)
    plt.xticks(rotation = 15)
    plt.title(f'{i}')
    k += 1

plt.suptitle('Plant Health Status')
plt.show()

# %%
plt.subplots(3,4,figsize=(16,12))
plt.subplots_adjust(wspace=0.3, hspace=0.3)

columns = ['Soil_Moisture', 'Ambient_Temperature', 'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH',
       'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level', 'Chlorophyll_Content', 'Electrochemical_Signal']
k = 1
for i in columns:
    plt.subplot(3,4,k)
    sns.barplot(y = i, x = 'Plant_ID', data = plants_df)
    plt.title(f'{i}')
    k += 1

plt.show()

# %% [markdown]
# ## Data Splitting

# %%
from sklearn.preprocessing import LabelEncoder
Y = plants_df['Plant_Health_Status']
le = LabelEncoder()
Y = le.fit_transform(Y)

# %%
X = plants_df.drop(columns='Plant_Health_Status')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train.shape, y_train.shape
# Out:
# ((960, 14), (960,))

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Column Transformer

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers=[('scaler',StandardScaler(),plants_df.select_dtypes(include='number').columns[1:-2]),
                                     ('onehot',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),['Plant_ID','Day','Time'])], 
                       remainder='drop',sparse_threshold=0)
ct
# Out:
# ColumnTransformer(sparse_threshold=0,
#                   transformers=[('scaler', StandardScaler(),
#                                  Index(['Soil_Moisture', 'Ambient_Temperature', 'Soil_Temperature', 'Humidity',
#        'Light_Intensity', 'Soil_pH', 'Nitrogen_Level', 'Phosphorus_Level',
#        'Potassium_Level', 'Chlorophyll_Content', 'Electrochemical_Signal'],
#       dtype='object')),
#                                 ('onehot',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['Plant_ID', 'Day', 'Time'])])

# %% [markdown]
# ## Model Selection

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB, CategoricalNB, ComplementNB, BernoulliNB, GaussianNB

models = {
    'log_reg': LogisticRegression(),
    'svm': SVC(),
    'knn': KNeighborsClassifier(),
    'dt': DecisionTreeClassifier(),
    'random': RandomForestClassifier(),
    'extra': ExtraTreesClassifier(),
    'gbt': GradientBoostingClassifier(),
    'hgbt': HistGradientBoostingClassifier(),
    'mnb': MultinomialNB(),
    'cnb': CategoricalNB(),
    'cmp_nb': ComplementNB(),
    'bnb': BernoulliNB(),
    'gnb': GaussianNB()
}

# %%
from sklearn.model_selection import cross_val_score
X_preprocessed = ct.fit_transform(X)

for i in models.keys():
    scores = cross_val_score(models[i], X, Y, cv = 5)
    print(f'{i}: {scores} and {scores.mean()}')
# Out:
# log_reg: [0.725      0.74166667 0.68333333 0.71666667 0.67916667] and 0.7091666666666667
# svm: [0.41666667 0.41666667 0.41666667 0.41666667 0.41666667] and 0.4166666666666667
# knn: [0.5375     0.52916667 0.53333333 0.54583333 0.55833333] and 0.5408333333333333
# dt: [0.99583333 1.         0.99166667 0.99583333 0.99166667] and 0.9949999999999999
# random: [0.99583333 0.99583333 0.99166667 0.99583333 0.99166667] and 0.9941666666666666
# extra: [0.95       0.92916667 0.94583333 0.90833333 0.84166667] and 0.915
# gbt: [0.99583333 0.99583333 0.99166667 0.99583333 0.99583333] and 0.9950000000000001
# hgbt: [0.99583333 1.         1.         0.99583333 1.        ] and 0.9983333333333334
# mnb: [0.43333333 0.54166667 0.49583333 0.5        0.48333333] and 0.49083333333333334
# cnb: [0.87083333 0.8625     0.75833333 0.71666667        nan] and nan
# cmp_nb: [0.44583333 0.525      0.45416667 0.51666667 0.46666667] and 0.48166666666666674
# bnb: [0.41666667 0.41666667 0.41666667 0.41666667 0.41666667] and 0.4166666666666667
# gnb: [0.84583333 0.84166667 0.8375     0.775      0.74166667] and 0.8083333333333332

# %% [markdown]
# ## Model Building

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline(steps=[('preprocessor', ct), ('model', DecisionTreeClassifier())])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(sparse_threshold=0,
#                                    transformers=[('scaler', StandardScaler(),
#                                                   Index(['Soil_Moisture', 'Ambient_Temperature', 'Soil_Temperature', 'Humidity',
#        'Light_Intensity', 'Soil_pH', 'Nitrogen_Level', 'Phosphorus_Level',
#        'Potassium_Level', 'Chlorophyll_Content', 'Electrochemical_Signal'],
#       dtype='object')),
#                                                  ('onehot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Plant_ID', 'Day',
#                                                    'Time'])])),
#                 ('model', DecisionTreeClassifier())])

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import precision_score, recall_score

y_pred = pipe.predict(X_test)
print('Accuracy: ', pipe.score(X_test, y_test))
print('Precision: ', precision_score(y_test, y_pred, average='macro'))
print('Recall: ', recall_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy:  0.9958333333333333
# Precision:  0.9963369963369964
# Recall:  0.996078431372549

# %%
pipe.classes_
# Out:
# array([0, 1, 2])
